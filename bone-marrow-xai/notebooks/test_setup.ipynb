# %%
import pandas as pd
import numpy as np
import sklearn
import GEOparse
import pyarrow

print(f"Pandas version: {pd.__version__}")
print(f"Scikit-Learn version: {sklearn.__version__}")
print("System is ready for Bioinformatics.")
# Out:
# Fixed.
# Pandas version: 2.3.3
# Scikit-Learn version: 1.7.2
# System is ready for Bioinformatics.
